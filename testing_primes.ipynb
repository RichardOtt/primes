# %% [markdown]
# Some quick testing of the code.
#
# If you change the code in `primes.py`, you'll need to restart the kernel (Kernel menu, Restart Kernel) and re-run the cells. This is because, by default, imports only run once. So it will remember the code as it was when it read the file the first time. Restarting the kernel purges that memory and gives a fresh start.

# %%
import primes

# %% [markdown]
# Are the primes working?

# %%
primes.is_prime(5)

# %%
primes.is_prime(10)

# %%
for n in range(1,20):
    print(n, primes.is_prime(n))

# %% [markdown]
# Can I get a few reasonable numbers of primes?

# %%
primes.first_n_primes(1)

# %%
primes.first_n_primes(10)

# %% [markdown]
# Really should do more testing here.
